# %%
import pandas as pandas

# %%
from pathlib import Path
evidence_dir = Path.home() / "Desktop" / "Persistent_Folder" / "Workspace" / "day-01-evidence"
print("ready")
print(evidence_dir)
# Out:
# ready
# /home/labuser/Desktop/Persistent_Folder/Workspace/day-01-evidence

# %%
from pathlib import Path
dataset_hint = Path.home() / "Desktop" / "Persistent_Folder" / "Workspace" / "day-01-evidence" / "source-extract" / "insurance policy data.xlsx"
fallback_hint = Path.home() / "Desktop" / "Persistent_Folder" / "Workspace" / "day-01-evidence" / "source-extract" / "Sample - Superstore.xls"
print("Primary dataset:", dataset_hint)
print("Fallback dataset: ", fallback_hint)
print("Evidence foler exists:", evidence_dir.exists())
# Out:
# Primary dataset: /home/labuser/Desktop/Persistent_Folder/Workspace/day-01-evidence/source-extract/insurance policy data.xlsx
# Fallback dataset:  /home/labuser/Desktop/Persistent_Folder/Workspace/day-01-evidence/source-extract/Sample - Superstore.xls
# Evidence foler exists: True
